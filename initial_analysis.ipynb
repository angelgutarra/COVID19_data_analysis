# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Aug 31 21:35:00 2020

@author: Angel

The data was gathered by The COVID Tracking Project 
https://covidtracking.com/data/api
"""

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
resp = requests.get("https://api.covidtracking.com/v1/us/daily.json")
data = resp.json()

# loaded data into dateframe
df = pd.DataFrame.from_dict(data)

# %%
# brief overview of the data.
print(df.describe())
# Out:
#                date      states      positive      negative       pending  \
# count  2.230000e+02  223.000000  2.230000e+02  2.230000e+02    181.000000
# mean   2.020050e+07   45.390135  1.826938e+06  1.898166e+07   7549.767956
# std    2.120325e+02   20.866053  1.869284e+06  2.219930e+07  13681.783664
# min    2.020012e+07    2.000000  0.000000e+00  0.000000e+00    103.000000
# 25%    2.020032e+07   56.000000  1.188300e+04  7.616500e+04   2133.000000
# 50%    2.020051e+07   56.000000  1.375165e+06  8.340605e+06   3330.000000
# 75%    2.020071e+07   56.000000  2.958680e+06  3.363648e+07   4206.000000
# max    2.020083e+07   56.000000  5.999459e+06  7.174944e+07  65709.000000
#
#        hospitalizedCurrently  hospitalizedCumulative  inIcuCurrently  \
# count             168.000000              181.000000       159.00000
# mean            41097.017857           186489.259669      8671.63522
# std             14993.239963           115437.097201      3181.39719
# ...

# %%
print(df.dtypes)
# Out:
# date                          int64
# states                        int64
# positive                      int64
# negative                      int64
# pending                     float64
# hospitalizedCurrently       float64
# hospitalizedCumulative      float64
# inIcuCurrently              float64
# inIcuCumulative             float64
# onVentilatorCurrently       float64
# onVentilatorCumulative      float64
# recovered                   float64
# dateChecked                  object
# death                       float64
# hospitalized                float64
# lastModified                 object
# total                         int64
# totalTestResults              int64
# posNeg                        int64
# deathIncrease                 int64
# hospitalizedIncrease          int64
# negativeIncrease              int64
# positiveIncrease              int64
# totalTestResultsIncrease      int64
# hash                         object
# dtype: object

# %%
# states are the number of states and territories which
# were included for the day.
df['states']
# Out:
# 0      56
# 1      56
# 2      56
# 3      56
# 4      56
#        ..
# 218     2
# 219     2
# 220     2
# 221     2
# 222     2
# Name: states, Length: 223, dtype: int64

# %%
sns.pairplot(df.loc[0:4,df.dtypes == 'float64'])

# %%
# the earliest data was on Jan 1, 2020
# the last day will change depending on
# the update and downlowd of new data
# currently Aug 31, 2020
print(df['date'])
# Out:
# 0      20200831
# 1      20200830
# 2      20200829
# 3      20200828
# 4      20200827
#          ...
# 218    20200126
# 219    20200125
# 220    20200124
# 221    20200123
# 222    20200122
# Name: date, Length: 223, dtype: int64

# %%
sns.set()
plt.plot(df['positive'], df['hospitalizedCumulative'])
plt.xlabel("positive test cases")
plt.ylabel("hospitalized cumulative")
# Out:
# Text(0, 0.5, 'hospitalized cumulative')
